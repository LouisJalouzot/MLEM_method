# %%
from src.utils import encode_df
import pandas as pd

# %%
df = pd.read_csv("datasets/relative_clause.csv")
sentences = df["sentence"].tolist()
df = df.drop(columns="sentence")

# %%
df.apply(lambda x: ", ".join(x.astype(str)), axis=1).value_counts()
